# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cars_advanced.csv')
# print(df.head())

# Replacing a value in column with another value
# df['Brand'].replace('BMW', 'see i told ya', inplace=True)
# print(df.head())

# df = df.fillna('This is a static Test')
# df

# %%
df = df.dropna(subset=['Brand', 'Price (USD)'])
df
# Out:
#     Car          Brand     Model  Year Engine Size Fuel Type  Mileage (km)  \
# 0     1         Toyota   Corolla  2018        1.8L    Petrol       42000.0
# 1     2          Honda     Civic  2020        2.0L    petrol       25000.0
# 2     3           Ford     Focus  2017        1.5L    Diesel       60000.0
# 3     4        Hyundai   Elantra  2019         NaN    Petrol       35000.0
# 5     6  Mercedes-Benz   C Class  2018        2.0L    Petrol       40000.0
# 6     7          Tesla   Model 3  2021    Electric  electric       15000.0
# 7     8            Kia    Optima  2017        2.4L    Petrol       50000.0
# 8     9           Audi        A4  2019        2.0L    Diesel       30000.0
# 9    10      Chevrolet    Malibu  2016        1.5L    Petrol        -500.0
# 10   11          Honda     Civic  2020        2.0L    Petrol       25000.0
# 11   12           Ford     Focus  2017        1.5L    Diesel       60000.0
# ...

# %%
# df.rename(columns={'Price (USD)' : 'Price'}, inplace=True)
df = df.rename(columns={'Price (USD)' : 'Price'})
df
# Out:
#     Car          Brand     Model  Year Engine Size Fuel Type  Mileage (km)  \
# 0     1         Toyota   Corolla  2018        1.8L    Petrol       42000.0
# 1     2          Honda     Civic  2020        2.0L    petrol       25000.0
# 2     3           Ford     Focus  2017        1.5L    Diesel       60000.0
# 3     4        Hyundai   Elantra  2019         NaN    Petrol       35000.0
# 5     6  Mercedes-Benz   C Class  2018        2.0L    Petrol       40000.0
# 6     7          Tesla   Model 3  2021    Electric  electric       15000.0
# 7     8            Kia    Optima  2017        2.4L    Petrol       50000.0
# 8     9           Audi        A4  2019        2.0L    Diesel       30000.0
# 9    10      Chevrolet    Malibu  2016        1.5L    Petrol        -500.0
# 10   11          Honda     Civic  2020        2.0L    Petrol       25000.0
# 11   12           Ford     Focus  2017        1.5L    Diesel       60000.0
# ...

# %%
df = df.drop_duplicates(subset=['Brand'])
df
# Out:
#     Car          Brand     Model  Year Engine Size Fuel Type  Mileage (km)  \
# 0     1         Toyota   Corolla  2018        1.8L    Petrol       42000.0
# 1     2          Honda     Civic  2020        2.0L    petrol       25000.0
# 2     3           Ford     Focus  2017        1.5L    Diesel       60000.0
# 3     4        Hyundai   Elantra  2019         NaN    Petrol       35000.0
# 5     6  Mercedes-Benz   C Class  2018        2.0L    Petrol       40000.0
# 6     7          Tesla   Model 3  2021    Electric  electric       15000.0
# 7     8            Kia    Optima  2017        2.4L    Petrol       50000.0
# 8     9           Audi        A4  2019        2.0L    Diesel       30000.0
# 9    10      Chevrolet    Malibu  2016        1.5L    Petrol        -500.0
# 14   15            BMW  3 series  2016        2.0L    Diesel       70000.0
#
#       Price Owner Type
# 0   14500.0      First
# 1   18000.0      First
# 2   12500.0     Second
# 3   16000.0      first
# ...

# %%
df[df['Car'] > 5]
# Out:
#     Car          Brand     Model  Year Engine Size Fuel Type  Mileage (km)  \
# 5     6  Mercedes-Benz   C Class  2018        2.0L    Petrol       40000.0
# 6     7          Tesla   Model 3  2021    Electric  electric       15000.0
# 7     8            Kia    Optima  2017        2.4L    Petrol       50000.0
# 8     9           Audi        A4  2019        2.0L    Diesel       30000.0
# 9    10      Chevrolet    Malibu  2016        1.5L    Petrol        -500.0
# 14   15            BMW  3 series  2016        2.0L    Diesel       70000.0
#
#       Price Owner Type
# 5   28000.0      First
# 6   35000.0      First
# 7   13000.0     Second
# 8   27000.0     Second
# 9   11000.0      third
# 14  20000.0      third

# %%
# df['Year'] = df['Year'].replace({2017 : 0000})
# df.head(10)

# df.at[ 0, 'Car'] = np.nan
# df.info()

# df.sort_values(by='Year', inplace=True)

# %%
df['Year'].value_counts()
df
# Out:
#     Car          Brand     Model  Year Engine Size Fuel Type  Mileage (km)  \
# 0     1         Toyota   Corolla  2018        1.8L    Petrol       42000.0
# 1     2          Honda     Civic  2020        2.0L    petrol       25000.0
# 2     3           Ford     Focus  2017        1.5L    Diesel       60000.0
# 3     4        Hyundai   Elantra  2019         NaN    Petrol       35000.0
# 5     6  Mercedes-Benz   C Class  2018        2.0L    Petrol       40000.0
# 6     7          Tesla   Model 3  2021    Electric  electric       15000.0
# 7     8            Kia    Optima  2017        2.4L    Petrol       50000.0
# 8     9           Audi        A4  2019        2.0L    Diesel       30000.0
# 9    10      Chevrolet    Malibu  2016        1.5L    Petrol        -500.0
# 14   15            BMW  3 series  2016        2.0L    Diesel       70000.0
#
#       Price Owner Type
# 0   14500.0      First
# 1   18000.0      First
# 2   12500.0     Second
# 3   16000.0      first
# ...

# %%
ndf = df.sort_values(by='Year', inplace=False)

ndf
# Out:
#     Car          Brand     Model  Year Engine Size Fuel Type  Mileage (km)  \
# 14   15            BMW  3 series  2016        2.0L    Diesel       70000.0
# 9    10      Chevrolet    Malibu  2016        1.5L    Petrol        -500.0
# 2     3           Ford     Focus  2017        1.5L    Diesel       60000.0
# 7     8            Kia    Optima  2017        2.4L    Petrol       50000.0
# 5     6  Mercedes-Benz   C Class  2018        2.0L    Petrol       40000.0
# 0     1         Toyota   Corolla  2018        1.8L    Petrol       42000.0
# 8     9           Audi        A4  2019        2.0L    Diesel       30000.0
# 3     4        Hyundai   Elantra  2019         NaN    Petrol       35000.0
# 1     2          Honda     Civic  2020        2.0L    petrol       25000.0
# 6     7          Tesla   Model 3  2021    Electric  electric       15000.0
#
#       Price Owner Type
# 14  20000.0      third
# 9   11000.0      third
# 2   12500.0     Second
# 7   13000.0     Second
# ...

# %%
df.reset_index(drop=True)
# Out:
#    Car          Brand     Model  Year Engine Size Fuel Type  Mileage (km)  \
# 0    1         Toyota   Corolla  2018        1.8L    Petrol       42000.0
# 1    2          Honda     Civic  2020        2.0L    petrol       25000.0
# 2    3           Ford     Focus  2017        1.5L    Diesel       60000.0
# 3    4        Hyundai   Elantra  2019         NaN    Petrol       35000.0
# 4    6  Mercedes-Benz   C Class  2018        2.0L    Petrol       40000.0
# 5    7          Tesla   Model 3  2021    Electric  electric       15000.0
# 6    8            Kia    Optima  2017        2.4L    Petrol       50000.0
# 7    9           Audi        A4  2019        2.0L    Diesel       30000.0
# 8   10      Chevrolet    Malibu  2016        1.5L    Petrol        -500.0
# 9   15            BMW  3 series  2016        2.0L    Diesel       70000.0
#
#      Price Owner Type
# 0  14500.0      First
# 1  18000.0      First
# 2  12500.0     Second
# 3  16000.0      first
# 4  28000.0      First
# ...

# %%
df
# Out:
#     Car          Brand     Model  Year Engine Size Fuel Type  Mileage (km)  \
# 0     1         Toyota   Corolla  2018        1.8L    Petrol       42000.0
# 1     2          Honda     Civic  2020        2.0L    petrol       25000.0
# 2     3           Ford     Focus  2017        1.5L    Diesel       60000.0
# 3     4        Hyundai   Elantra  2019         NaN    Petrol       35000.0
# 5     6  Mercedes-Benz   C Class  2018        2.0L    Petrol       40000.0
# 6     7          Tesla   Model 3  2021    Electric  electric       15000.0
# 7     8            Kia    Optima  2017        2.4L    Petrol       50000.0
# 8     9           Audi        A4  2019        2.0L    Diesel       30000.0
# 9    10      Chevrolet    Malibu  2016        1.5L    Petrol        -500.0
# 14   15            BMW  3 series  2016        2.0L    Diesel       70000.0
#
#       Price Owner Type
# 0   14500.0      First
# 1   18000.0      First
# 2   12500.0     Second
# 3   16000.0      first
# ...
